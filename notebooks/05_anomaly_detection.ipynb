# %% [markdown]
# # 05 — Hybrid Anomaly Detection & Exception Triage
#
# Evaluates deterministic business rules, Isolation Forest multivariate outlier scores, and servicer reconciliation conflicts.

# %%
import sys
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path('.').resolve().parent
sys.path.insert(0, str(PROJECT_ROOT))

from src.config.settings import PREDICTIONS_DIR

dossiers = pd.read_csv(PREDICTIONS_DIR / 'reviewer_exception_dossiers.csv')
print('Flagged Exception Dossiers count:', len(dossiers))
dossiers[['loan_id', 'anomaly_score', 'anomaly_severity', 'reviewer_action', 'top_drivers']].head(10)
# Out:
# Flagged Exception Dossiers count: 30
#       loan_id  anomaly_score anomaly_severity            reviewer_action  \
# 0  LC_1023494           37.6           MEDIUM  RECONCILE_SOURCE_CONFLICT
# 1  LC_1014061           36.3           MEDIUM  RECONCILE_SOURCE_CONFLICT
# 2  LC_1020348           35.1           MEDIUM  RECONCILE_SOURCE_CONFLICT
# 3  LC_1005572           34.2           MEDIUM  RECONCILE_SOURCE_CONFLICT
# 4  LC_1009749           33.9           MEDIUM  RECONCILE_SOURCE_CONFLICT
# 5  LC_1023479           33.0           MEDIUM  RECONCILE_SOURCE_CONFLICT
# 6  LC_1011792           32.8           MEDIUM  RECONCILE_SOURCE_CONFLICT
# 7  LC_1014518           32.8           MEDIUM  RECONCILE_SOURCE_CONFLICT
# 8  LC_1022165           31.9           MEDIUM  RECONCILE_SOURCE_CONFLICT
# 9  LC_1018012           31.8           MEDIUM  RECONCILE_SOURCE_CONFLICT
#
#                       top_drivers
# 0  source_reconciliation_conflict
# 1  source_reconciliation_conflict
# 2  source_reconciliation_conflict
# 3  source_reconciliation_conflict
# 4  source_reconciliation_conflict
# 5  source_reconciliation_conflict
# 6  source_reconciliation_conflict
# 7  source_reconciliation_conflict
# 8  source_reconciliation_conflict
# 9  source_reconciliation_conflict
