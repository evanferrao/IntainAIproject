# %% [markdown]
# # 07 — Grounded LLM Reviewer Copilot & Governance
#
# Demonstrates grounded retrieval over data dictionary and validation rules, loan review note generation, and audit logging.

# %%
import sys
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path('.').resolve().parent
sys.path.insert(0, str(PROJECT_ROOT))

from src.copilot.grounded_copilot import GroundedReviewerCopilot
from src.copilot.evaluation_suite import get_llm_evaluation_benchmarks

copilot = GroundedReviewerCopilot()
res = copilot.retrieve_field_definition('credit_score')
print(res['content'])
# Out:
# Definition for 'credit_score':
# | `credit_score` | `FLOAT` | Borrower FICO credit score at origination. | `300 – 850` | Source: `fico_range_low`/`high` |
# | `credit_score_band` | `VARCHAR(16)` | Risk tier category (Super Prime, Prime, Near Prime, Subprime, Deep Subprime). | Tier enum | Derived from `credit_score` |

# %%
benchmarks = get_llm_evaluation_benchmarks()
print('Loaded failure-mode benchmarks:', len(benchmarks))
for b in benchmarks:
    print(f'[{b["benchmark_id"]}] {b["failure_category"]}')
# Out:
# Loaded failure-mode benchmarks: 3
# [EVAL_VAGUE_01] Vague / Ambiguous Output
# [EVAL_UNSUPPORTED_01] Unsupported / Hallucinated Metric
# [EVAL_OVERCONFIDENT_01] Overconfident / Ungoverned Certainty
