# %% [markdown]
# # 04 — Markov State Transition & Survival Projections
#
# Estimates empirical 1-month transition matrices and generates multi-period cumulative default and prepayment absorption curves.

# %%
import sys
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path('.').resolve().parent
sys.path.insert(0, str(PROJECT_ROOT))

from src.config.settings import MODELS_DIR
from src.utils.serialization import load_model

# %%
markov = load_model(MODELS_DIR / 'markov_transition_model.joblib')
print('Global Transition Matrix:')
print(markov.global_transition_matrix)
# Out:
# Global Transition Matrix:
# next_state      CURRENT  DELINQUENT_30  DELINQUENT_60  DELINQUENT_90  DEFAULT  \
# current_status
# CURRENT          0.9352         0.0497         0.0000         0.0000   0.0000
# DELINQUENT_30    0.3131         0.0908         0.5961         0.0000   0.0000
# DELINQUENT_60    0.1304         0.0000         0.0456         0.8240   0.0000
# DELINQUENT_90    0.0000         0.0963         0.0000         0.1638   0.7399
# DEFAULT          0.0000         0.0000         0.0000         0.0000   1.0000
# PREPAID          0.0000         0.0000         0.0000         0.0000   0.0000
# CLOSED           0.0000         0.0000         0.0000         0.0000   0.0000
#
# next_state      PREPAID  CLOSED
# current_status
# CURRENT          0.0151     0.0
# DELINQUENT_30    0.0000     0.0
# DELINQUENT_60    0.0000     0.0
# DELINQUENT_90    0.0000     0.0
# DEFAULT          0.0000     0.0
# PREPAID          1.0000     0.0
# CLOSED           0.0000     1.0

# %%
proj_df = markov.project_multi_period(horizon_months=24)
proj_df.head(10)
# Out:
#    month  CURRENT  DELINQUENT_30  DELINQUENT_60  DELINQUENT_90  DEFAULT  \
# 0      0   1.0000         0.0000         0.0000         0.0000   0.0000
# 1      1   0.9352         0.0497         0.0000         0.0000   0.0000
# 2      2   0.8902         0.0510         0.0296         0.0000   0.0000
# 3      3   0.8523         0.0489         0.0317         0.0244   0.0000
# 4      4   0.8165         0.0491         0.0306         0.0302   0.0181
# 5      5   0.7830         0.0479         0.0307         0.0301   0.0404
# 6      6   0.7513         0.0462         0.0300         0.0302   0.0627
# 7      7   0.7209         0.0444         0.0289         0.0297   0.0850
# 8      8   0.6919         0.0427         0.0278         0.0287   0.1070
# 9      9   0.6641         0.0410         0.0267         0.0276   0.1282
#
#    PREPAID  CLOSED  cumulative_default  cumulative_prepayment
# 0   0.0000     0.0              0.0000                 0.0000
# 1   0.0151     0.0              0.0000                 0.0151
# 2   0.0292     0.0              0.0000                 0.0292
# 3   0.0427     0.0              0.0000                 0.0427
# 4   0.0555     0.0              0.0181                 0.0555
# 5   0.0679     0.0              0.0404                 0.0679
# 6   0.0797     0.0              0.0627                 0.0797
# 7   0.0910     0.0              0.0850                 0.0910
# 8   0.1019     0.0              0.1070                 0.1019
# 9   0.1124     0.0              0.1282                 0.1124
